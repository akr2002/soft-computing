# %%
import random
import string

# The target word we want to evolve to
TARGET = "The quick brown fox jumps over a lazy dog"

# GA parameters
POPULATION_SIZE = 100
MUTATION_RATE = 0.01  # probability of mutating each character
MAX_GENERATIONS = 10000

# Allowed characters (includes letters, punctuation, and space)
ALLOWED_CHARS = string.ascii_letters + " ,!?;:'\""

def random_candidate() -> str:
    """Generate a random candidate string of the same length as TARGET."""
    return ''.join(random.choice(ALLOWED_CHARS) for _ in range(len(TARGET)))

def fitness(candidate: str) -> int:
    """
    Calculate the fitness of a candidate.
    Fitness is defined as the number of characters that match the target in the correct position.
    """
    return sum(1 for a, b in zip(candidate, TARGET) if a == b)

def mutate(candidate: str) -> str:
    """
    Mutate the candidate string by randomly changing each character with probability MUTATION_RATE.
    """
    candidate_list = list(candidate)
    for i in range(len(candidate_list)):
        if random.random() < MUTATION_RATE:
            candidate_list[i] = random.choice(ALLOWED_CHARS)
    return ''.join(candidate_list)

def crossover(parent1: str, parent2: str) -> str:
    """
    Perform a one-point crossover between two parents.
    A random crossover point is chosen and the child inherits the first part from parent1 and the rest from parent2.
    """
    index = random.randint(0, len(parent1) - 1)
    child = parent1[:index] + parent2[index:]
    return child

def select_parent(population: list) -> str:
    """
    Select a parent from the population using tournament selection.
    A few candidates are picked at random, and the one with the highest fitness is chosen.
    """
    tournament_size = 5
    tournament = random.sample(population, tournament_size)
    tournament.sort(key=lambda candidate: fitness(candidate), reverse=True)
    return tournament[0]

def genetic_algorithm():
    # Initialize the population with random candidates
    population = [random_candidate() for _ in range(POPULATION_SIZE)]
    generation = 0

    while generation < MAX_GENERATIONS:
        # Sort population by fitness (highest fitness first)
        population.sort(key=lambda candidate: fitness(candidate), reverse=True)
        best_candidate = population[0]
        best_fit = fitness(best_candidate)
        print(f"Generation {generation}: Best = '{best_candidate}' Fitness = {best_fit}")

        # Check if we've reached the target
        if best_candidate == TARGET:
            print("Target reached!")
            return best_candidate

        new_population = []
        # Optionally: Use elitism by carrying the best candidate to the next generation
        new_population.append(best_candidate)

        # Generate new candidates until we have a full population
        while len(new_population) < POPULATION_SIZE:
            # Select two parents via tournament selection
            parent1 = select_parent(population)
            parent2 = select_parent(population)
            # Create a new candidate via crossover
            child = crossover(parent1, parent2)
            # Apply mutation to the child
            child = mutate(child)
            new_population.append(child)

        population = new_population
        generation += 1

    print("Maximum generations reached without finding the target.")
    return None

if __name__ == "__main__":
    genetic_algorithm()
# Out:
# Generation 0: Best = 'TiNU'yiuNxLZSGqp;d;cvczLDLtqewT,etv;Gou:?' Fitness = 3
# Generation 1: Best = 'dqeUzp:h 'ILPVwwYPx q,lyjWoIf"VfQiMQ!CexE' Fitness = 4
# Generation 2: Best = 'JXqLWuGcDjKJN yYaRVe!uuUaaCpenj; yAUC!zbp' Fitness = 5
# Generation 3: Best = 'TXqLWuGcDjKJN yYaRVe!uuUaaCpenj; yAUC!zbp' Fitness = 6
# Generation 86: Best = 'TKe quGcD bLodn f,x juDUs oDer ; lQzy doa' Fitness = 29
# Generation 87: Best = 'TKe quGcD bLodn f,x juDUs oDer ; lQzy doa' Fitness = 29
# Generation 88: Best = 'TKe quGcD bLodn f,x juDUs oDer ; lQzy doa' Fitness = 29
# Generation 89: Best = 'TKe quGcD bLodn f,x juDUs oDer ; lQzy doa' Fitness = 29
# Generation 90: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 91: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 92: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 93: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 94: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 95: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 96: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 97: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 98: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 99: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 100: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 101: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 102: Best = 'TKe quGcc bZown f,x juDUs oDer c lQzy doa' Fitness = 30
# Generation 103: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 104: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 105: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 106: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 107: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 108: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 109: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 110: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 111: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 112: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 113: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 114: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 115: Best = 'Tge quGcc bZown f,x juDUs over i lezy do'' Fitness = 31
# Generation 116: Best = 'TKe quZcc byown f,x juDps over i lezy do'' Fitness = 32
# Generation 117: Best = 'TKe quZcc byown f,x juDps over i lezy do'' Fitness = 32
# Generation 118: Best = 'TKe quZcc byown f,x juDps over i lezy do'' Fitness = 32
# Generation 119: Best = 'TKe quZcc byown f,x juDps over i lezy do'' Fitness = 32
# Generation 120: Best = 'TKe quZcc byown f,x juDps over i lezy do'' Fitness = 32
# Generation 121: Best = 'The quGcc bZown f,x juDps over i lezy do'' Fitness = 33
# Generation 122: Best = 'The quGcc bZown f,x juDps over i lezy do'' Fitness = 33
# Generation 123: Best = 'The quGcc bZown f,x juDps over i lezy do'' Fitness = 33
# Generation 124: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 125: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 126: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 127: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 128: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 129: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 130: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 131: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 132: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 133: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 134: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 135: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 136: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 137: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 138: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 139: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 140: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 141: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 142: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 143: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 144: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 145: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 146: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 147: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 148: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 149: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 150: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 151: Best = 'The quGcc bZown f,x juDps over i lazy do'' Fitness = 34
# Generation 152: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 153: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 154: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 155: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 156: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 157: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 158: Best = 'The quicc bzown f,x juDps over n lazy do'' Fitness = 35
# Generation 159: Best = 'The quicc brown fyx juDps over i lazy do'' Fitness = 36
# Generation 160: Best = 'The quicc brown fyx juDps over i lazy do'' Fitness = 36
# Generation 161: Best = 'The quicc brown fyx juDps over i lazy do'' Fitness = 36
# Generation 162: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 163: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 164: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 165: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 166: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 167: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 168: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 169: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 170: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 171: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 172: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 173: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 174: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 175: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 176: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 177: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 178: Best = 'The quicc brown f,x juDps over i lazy dog' Fitness = 37
# Generation 179: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 180: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 181: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 182: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 183: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 184: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 185: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 186: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
# Generation 187: Best = 'The quicc brown fyx juDps over a lazy dog' Fitness = 38
