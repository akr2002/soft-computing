# %%
import random
import string

# The target word we want to evolve to
TARGET = "The quick brown fox jumps over a lazy dog"

# GA parameters
POPULATION_SIZE = 100
MUTATION_RATE = 0.01  # probability of mutating each character
MAX_GENERATIONS = 10000

# Allowed characters (includes letters, punctuation, and space)
ALLOWED_CHARS = string.ascii_letters + " ,!?;:'\""

def random_candidate() -> str:
    """Generate a random candidate string of the same length as TARGET."""
    return ''.join(random.choice(ALLOWED_CHARS) for _ in range(len(TARGET)))

def fitness(candidate: str) -> int:
    """
    Calculate the fitness of a candidate.
    Fitness is defined as the number of characters that match the target in the correct position.
    """
    return sum(1 for a, b in zip(candidate, TARGET) if a == b)

def mutate(candidate: str) -> str:
    """
    Mutate the candidate string by randomly changing each character with probability MUTATION_RATE.
    """
    candidate_list = list(candidate)
    for i in range(len(candidate_list)):
        if random.random() < MUTATION_RATE:
            candidate_list[i] = random.choice(ALLOWED_CHARS)
    return ''.join(candidate_list)

def crossover(parent1: str, parent2: str) -> str:
    """
    Perform a one-point crossover between two parents.
    A random crossover point is chosen and the child inherits the first part from parent1 and the rest from parent2.
    """
    index = random.randint(0, len(parent1) - 1)
    child = parent1[:index] + parent2[index:]
    return child

def select_parent(population: list) -> str:
    """
    Select a parent from the population using tournament selection.
    A few candidates are picked at random, and the one with the highest fitness is chosen.
    """
    tournament_size = 5
    tournament = random.sample(population, tournament_size)
    tournament.sort(key=lambda candidate: fitness(candidate), reverse=True)
    return tournament[0]

def genetic_algorithm():
    # Initialize the population with random candidates
    population = [random_candidate() for _ in range(POPULATION_SIZE)]
    generation = 0

    while generation < MAX_GENERATIONS:
        # Sort population by fitness (highest fitness first)
        population.sort(key=lambda candidate: fitness(candidate), reverse=True)
        best_candidate = population[0]
        best_fit = fitness(best_candidate)
        print(f"Generation {generation}: Best = '{best_candidate}' Fitness = {best_fit}")

        # Check if we've reached the target
        if best_candidate == TARGET:
            print("Target reached!")
            return best_candidate

        new_population = []
        # Optionally: Use elitism by carrying the best candidate to the next generation
        new_population.append(best_candidate)

        # Generate new candidates until we have a full population
        while len(new_population) < POPULATION_SIZE:
            # Select two parents via tournament selection
            parent1 = select_parent(population)
            parent2 = select_parent(population)
            # Create a new candidate via crossover
            child = crossover(parent1, parent2)
            # Apply mutation to the child
            child = mutate(child)
            new_population.append(child)

        population = new_population
        generation += 1

    print("Maximum generations reached without finding the target.")
    return None

if __name__ == "__main__":
    genetic_algorithm()
# Out:
# Generation 0: Best = 'CubDj;ecrBXFE?a"KoAbn!FZE dUXhUTvqEzYCVkX' Fitness = 4
# Generation 1: Best = 'CubDj;ecrBXFE?a"KoAbn!FZE dUXhUTvqEzYCVkX' Fitness = 4
# Generation 2: Best = 'TKFjokbcAjbZoBhJVvpCtwJbM"sE'emIFJUu' ,oC' Fitness = 6
# Generation 3: Best = 'TKFjokbcAjbZoBhJVvpCtwFZE dMXhwZHJUu' ,os' Fitness = 7
# Generation 4: Best = 'TKFjokbcAjb?oBhIKoAbn!FZE dUXhwZHJUu' ,os' Fitness = 8
# Generation 5: Best = 'TKFjokbcAjbZownieRvtFe gxxo?SAQVHJUu' ,oX' Fitness = 9
# Generation 6: Best = 'TeeQcZOcAjbZownieRvtFe gxxo?SAQP uyR' ,os' Fitness = 11
# Generation 7: Best = 'TeeQcZOcAjbZownieRvtFe gxxo?SAQP uyR' ,os' Fitness = 11
# Generation 8: Best = 'TeeQcZOckJMHowa"KoAbn!FZE dUiAQV uaz' ,os' Fitness = 13
# Generation 9: Best = 'TeeQcZOcAjbZowniKoAbn!FZE dUSAQV uaz' ,os' Fitness = 14
# Generation 10: Best = 'TeeQcZOckjbZowniKoAbn!FZE dUSAQV uaz' ,os' Fitness = 15
# Generation 11: Best = 'TeeQcZOckjbZowniKoAbn!FZE dUSAQV uaz' ,os' Fitness = 15
# Generation 12: Best = 'TeeQcZOckjbZowniKoAbn! gxxovSAQV uaz' ,os' Fitness = 16
# Generation 13: Best = 'TeeQcZOckjbZowniKoAbn! gxxovSAQV uaz' ,os' Fitness = 16
# Generation 14: Best = 'TeeQcZOckjbZowniKoAbn! gxxovSAQV uaz' ,os' Fitness = 16
# Generation 15: Best = 'TeeQcZOckjbZowniKoAbn! gxxovSAQV uaz' ,os' Fitness = 16
# Generation 16: Best = 'TeeQcZOckjbZowniKoAxn!FZE ovSAQV uaz' ,os' Fitness = 17
# Generation 17: Best = 'TeeQcZOckjbZowniKoAxn!FZE ovSAQV uaz' ,os' Fitness = 17
# Generation 18: Best = 'TeeQcZOckjbZowniKoAxn!FZE ovSAQV uaz' ,os' Fitness = 17
# Generation 19: Best = 'TeeQcZOckjbZowniKoAxn!FZE ovSAQV uaz' ,os' Fitness = 17
# Generation 20: Best = 'TeeQTZOckjbZowniKoAbo!mgx ovSAQV Gaz' ,os' Fitness = 18
# Generation 21: Best = 'TeeQTZOckjbZowniKoAbo!mgx ovSAQV Gaz' ,os' Fitness = 18
# Generation 22: Best = 'TeeQcZOck bZowniKoAKn!mgx ovXAQV uaz' "os' Fitness = 19
# Generation 23: Best = 'TeeQcZOck bZowniKoAKn!mgx ovXAQV uaz' "os' Fitness = 19
# Generation 24: Best = 'TeeQcCOck bxowniKoAbn!mgx ovXAQa uaz' ,os' Fitness = 20
# Generation 25: Best = 'TeeQcCOck bxowniKoAbn!mgx ovXAQa uaz' ,os' Fitness = 20
# Generation 26: Best = 'TeeQcuOck bxowniKoAbn!mgx ovSA V uaz' "os' Fitness = 21
# Generation 27: Best = 'TeeQcuOck bxowniKoAbn!mgx ovSA a uaz' ,os' Fitness = 22
# Generation 28: Best = 'TeeQcuOck bxowniKoAbn!mgx ovSA a uaz' ,os' Fitness = 22
# Generation 29: Best = 'TeeQcuOck bxowniKoAbn!mgx ovSA a uaz' ,os' Fitness = 22
# Generation 30: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,os' Fitness = 23
# Generation 31: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,os' Fitness = 23
# Generation 32: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,os' Fitness = 23
# Generation 33: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,os' Fitness = 23
# Generation 34: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,os' Fitness = 23
# Generation 35: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,og' Fitness = 24
# Generation 36: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,og' Fitness = 24
# Generation 37: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,og' Fitness = 24
# Generation 38: Best = 'TeeQcuOck bxowniKoAbj!mg, ovSA a uaz' ,og' Fitness = 24
# Generation 39: Best = 'Teef;uOck bxownisoxbjomg, ovSA a uaz' ,og' Fitness = 25
# Generation 40: Best = 'Teef;uOck bxownisoxbjomg, ovSA a uaz' ,og' Fitness = 25
# Generation 41: Best = 'Teef;uOck bxownisoxbjomg, ovSA a uaz' ,og' Fitness = 25
# Generation 42: Best = 'Teef;uOck bxownisoxbjomg, ovSA a uaz' ,og' Fitness = 25
# Generation 43: Best = 'TeeQquOck bxowniboxbj!mg, ovSA a uaz' ,og' Fitness = 26
# Generation 44: Best = 'TeeQquOck bxowniboxbj!mg, ovSA a uaz' ,og' Fitness = 26
# Generation 45: Best = 'TeeQquOck bxowniboxbj!mg, ovSA a uaz' ,og' Fitness = 26
# Generation 46: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 47: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 48: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 49: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 50: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 51: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 52: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 53: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 54: Best = 'TeeQquOck bxownisox j!mg, ovSA a uaz' ,og' Fitness = 27
# Generation 55: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 56: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 57: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 58: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 59: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 60: Best = 'Tee quDck bxownisox j!mV, ov!A a zaz' ,og' Fitness = 28
# Generation 61: Best = 'Tee quDck bxownisox j!mV, ov!A a qazy ,og' Fitness = 29
# Generation 62: Best = 'Tee quDck bxownisox j!mV, ov!A a qazy ,og' Fitness = 29
# Generation 63: Best = 'Tee quDck bxownisox j!mV, ov!A a qazy ,og' Fitness = 29
# Generation 64: Best = 'Tee quDck bxownisox j!mV, ov!A a qazy ,og' Fitness = 29
# Generation 65: Best = 'Tee quDck bxownisox j!mV, ov!A a qazy ,og' Fitness = 29
# Generation 66: Best = 'Tee quDck bxownisox j!mgs ov!A a qazy ,og' Fitness = 30
# Generation 67: Best = 'Tee quDck bxownisox j!mgs ov!A a qazy ,og' Fitness = 30
# Generation 68: Best = 'Tee quDck bxownisox j!mgs ov!A a qazy ,og' Fitness = 30
# Generation 69: Best = 'Tee quDck bxownisox j!mgs ov!A a qazy ,og' Fitness = 30
# Generation 70: Best = 'Tee quDck bxownisox j!mgs ov!A a qazy ,og' Fitness = 30
# Generation 71: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 72: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 73: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 74: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 75: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 76: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 77: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 78: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 79: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 80: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 81: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 82: Best = 'Tee quick bxownisox j!mgs ov!A a qazy ,og' Fitness = 31
# Generation 83: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 84: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 85: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 86: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 87: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 88: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 89: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 90: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 91: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 92: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 93: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 94: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 95: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 96: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 97: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 98: Best = 'Tee quick brownisox j!mgs ov!A a qazy ,og' Fitness = 32
# Generation 99: Best = 'Tee quick brownisox j!mgs oveA a qazy Aog' Fitness = 33
# Generation 100: Best = 'Tee quick brownisox j!mgs oveA a qazy Aog' Fitness = 33
# Generation 101: Best = 'Tee quick brownisox j!mgs oveA a qazy Aog' Fitness = 33
# Generation 102: Best = 'Tee quick brownisox j!mgs oveA a qazy Aog' Fitness = 33
# Generation 103: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 104: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 105: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 106: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 107: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 108: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 109: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 110: Best = 'The quick brownisox j!mgs oveA a qazy Aog' Fitness = 34
# Generation 111: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 112: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 113: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 114: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 115: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 116: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 117: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 118: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 119: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 120: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 121: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 122: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 123: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 124: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 125: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 126: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 127: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 128: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 129: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 130: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 131: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 132: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 133: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 134: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 135: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 136: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 137: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 138: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 139: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 140: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 141: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 142: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 143: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 144: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 145: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 146: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 147: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 148: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 149: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 150: Best = 'The quick brownifox j!mgs oveA a qazy Aog' Fitness = 35
# Generation 151: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 152: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 153: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 154: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 155: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 156: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 157: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 158: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 159: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 160: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 161: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 162: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 163: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 164: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 165: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 166: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 167: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 168: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 169: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 170: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 171: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 172: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 173: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 174: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 175: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 176: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 177: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 178: Best = 'The quick brown;fox j!mTs oveA a lazy Log' Fitness = 36
# Generation 179: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 180: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 181: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 182: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 183: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 184: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 185: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 186: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 187: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 188: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 189: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 190: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 191: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 192: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 193: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 194: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 195: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 196: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 197: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 198: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 199: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 200: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 201: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 202: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 203: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 204: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 205: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 206: Best = 'The quick brown fox j!mTs ovea a lazy Fog' Fitness = 37
# Generation 207: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 208: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 209: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 210: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 211: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 212: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 213: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 214: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 215: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 216: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 217: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 218: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 219: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 220: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 221: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 222: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 223: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 224: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 225: Best = 'The quick brown fox j!m,s over a lazy Log' Fitness = 38
# Generation 226: Best = 'The quick brown fox j!mps over a lazy Log' Fitness = 39
# Generation 227: Best = 'The quick brown fox j!mps over a lazy Log' Fitness = 39
# Generation 228: Best = 'The quick brown fox j!mps over a lazy Log' Fitness = 39
# Generation 229: Best = 'The quick brown fox j!mps over a lazy Log' Fitness = 39
# Generation 230: Best = 'The quick brown fox j!mps over a lazy Log' Fitness = 39
# Generation 231: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 232: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 233: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 234: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 235: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 236: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 237: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 238: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 239: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 240: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 241: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 242: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 243: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 244: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 245: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 246: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 247: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 248: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 249: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 250: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 251: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 252: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 253: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 254: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 255: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 256: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 257: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 258: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 259: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 260: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 261: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 262: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 263: Best = 'The quick brown fox j!mps over a lazy dog' Fitness = 40
# Generation 264: Best = 'The quick brown fox jumps over a lazy dog' Fitness = 41
# Target reached!
